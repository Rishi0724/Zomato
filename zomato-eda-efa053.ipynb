# %% [markdown]
# ![ZOMATO FOOD DELIVERY](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTg5r4x_9PMOTZoFh3hPcr6wsl1zSv4aMZvmQ&usqp=CAU)
# # ZOMATO FOOD DELIVERY
# **Zomato is an Indian multinational restaurant aggregator and food delivery company founded by Deepinder Goyal and Pankaj Chaddah in 2008. Zomato provides information, menus and user-reviews of restaurants as well as food delivery options from partner restaurants in select cities. Wikipedia**

# %%
import numpy as np # linear algebra
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data=pd.read_csv('../input/zomato-restaurants-data/zomato.csv',encoding="latin-1")
data.head()

# %%
data.shape

# %%
data.columns

# %%
data.info()

# %%
data.describe()

# %% [markdown]
# **#these are only integer/float features**

# %%
#lets check the missing values
data.isnull().sum()

# %%
[features for features in data.columns if data[features].isnull().sum()>0]

# %%
plt.figure(figsize=(12,6))
sns.heatmap(data.isnull(), cbar=False,yticklabels=False,cmap="YlGnBu")

# %% [markdown]
# # very very less number of data are misssing thats why we can  see the thin black line in the above

# %%
pip install openpyxl

# %%
data_country=pd.read_excel('../input/zomato-restaurants-data/Country-Code.xlsx')
data_country.head()

# %%
data.columns

# %% [markdown]
# # copy the _image address_ from website/chrome and  paste it in
# # ![write any thing here related to image](paset the url of image address here https/....)

# %% [markdown]
# <img src='https://docs.microsoft.com/en-us/power-query/images/left-outer-join-operation.png'>

# %% [markdown]
# # merge the table

# %%
final_df=pd.merge(data,data_country,on='Country Code',how='left')
final_df.head(3)

# %%
final_df.dtypes

# %% [markdown]
# # zomato is mostly availabe in india ,a/c to the records

# %%
final_df.Country.value_counts()

# %%
country_name=final_df.Country.value_counts().index
country_name

# %%
country_value=final_df.Country.value_counts().values
country_value

# %%
plt.pie(country_value[:3],labels=country_name[:3],autopct='%1.3f%%')

# %% [markdown]
# # Maxm records or transaction are from India,then US,UK

# %% [markdown]
# # Groupby

# %% [markdown]
# ![](https://miro.medium.com/max/603/0*5Zzcwe-rlxz-EQ_N)

# %% [markdown]
# ![groupby](https://miro.medium.com/max/1400/0*m-puRNwcnUl5zZ4O)

# %%
final_df.groupby(['Aggregate rating','Rating color','Rating text']).size()

# %%
ratings=final_df.groupby(['Aggregate rating','Rating color','Rating text']).size().reset_index().rename(columns={0:'Rating counts'})
ratings

# %% [markdown]
# # #observation
# 1.  when rating is btwn 4.5 to 4.9--------------->Excellent
# 2.  when rating is btwn 4.0 to 4.4--------------->very good
# 3.  when rating is btwn 3.5 to 3.9--------------->good
# 4.  when rating is btwn 3.0 to 3.4--------------->average
# 5.  when rating is btwn 2.5 to 2.9--------------->average
# 6.  when rating is btwn 2.0 to 2.4--------------->poor

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='Aggregate rating',y='Rating counts',data=ratings)

# %%
#palette is used to give color as per your reqiirement or color mapping
plt.figure(figsize=(12,6))
sns.barplot(x='Aggregate rating',y='Rating counts',data=ratings,hue='Rating color',palette=['beige','red','orange','yellow','green','green'])

# %% [markdown]
# # maxm number of rating are btwn 2.5 to 3.4

# %%
sns.countplot(x='Rating color',data=ratings,palette=['beige','red','orange','yellow','green','green'])

# %%
final_df.columns

# %%
final_df.groupby(['Aggregate rating','Country']).size().reset_index().head()

# %% [markdown]
# **Maxm number of 0 ratings are from indian customers**

# %%
final_df.groupby(['Country','Currency']).size().reset_index()

# %%
final_df.columns

# %%
final_df.groupby(['Country','Has Online delivery']).size().reset_index()

# %% [markdown]
# # country in which food delivery online

# %%
final_df[final_df['Has Online delivery']=='Yes'].Country.value_counts()

# %% [markdown]
# **online delivery in india and uae only from given dataset**

# %%
final_df.groupby(['Has Online delivery']).size().reset_index()

# %%
#pie chart w.r.t city
final_df.City.value_counts().index

# %%
city_value=final_df.City.value_counts().values
city_labels=final_df.City.value_counts().index

# %%
plt.pie(city_value[:5],labels=city_labels[:5],autopct='%1.3f%%')

# %% [markdown]
# # Maxm nuber of transaction happen from New delhi then grugram ,Noida
